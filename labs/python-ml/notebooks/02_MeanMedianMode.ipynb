# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy

# %% [markdown]
# ## Mean vs. Median

# %% [markdown]
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:

# %%
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# np.float64(26976.596919631338)

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# np.float64(27127.261593265677)

# %% [markdown]
# Now we'll add Jeff Bezos into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000000000])

# %% [markdown]
# The median won't change much, but the mean does:

# %%
np.median(incomes)
# Out:
# np.float64(27128.618534839658)

# %%
np.mean(incomes)
# Out:
# np.float64(126963.90052957839)

# %% [markdown]
# ## Mode

# %% [markdown]
# Next, let's generate some fake age data for 500 people:

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([28, 19, 25, 46, 64, 61, 50, 73, 41, 60, 22, 49, 83, 82, 75, 62, 30,
#        30, 58, 65, 79, 87, 78, 31, 71, 52, 40, 38, 55, 88, 38, 31, 80, 28,
#        26, 23, 48, 24, 58, 49, 69, 77, 80, 28, 56, 26, 72, 59, 84, 61, 27,
#        44, 19, 71, 60, 48, 55, 56, 44, 32, 20, 76, 80, 67, 77, 80, 88, 28,
#        51, 41, 45, 40, 72, 70, 75, 68, 24, 29, 54, 80, 75, 87, 62, 69, 89,
#        48, 74, 46, 63, 75, 71, 77, 40, 42, 82, 45, 48, 57, 52, 49, 73, 21,
#        67, 81, 76, 45, 80, 65, 60, 48, 23, 28, 88, 37, 52, 72, 29, 43, 21,
#        32, 71, 49, 68, 26, 83, 21, 80, 56, 42, 81, 41, 49, 83, 52, 23, 62,
#        44, 67, 79, 21, 53, 88, 88, 70, 21, 76, 78, 43, 38, 53, 54, 42, 67,
#        66, 67, 61, 88, 82, 89, 69, 68, 20, 84, 84, 62, 64, 24, 70, 61, 25,
#        44, 64, 71, 82, 72, 44, 81, 72, 50, 83, 24, 88, 51, 70, 32, 37, 67,
#        48, 32, 57, 76, 55, 80, 22, 67, 50, 37, 39, 50, 47, 81, 83, 89, 22,
#        82, 70, 51, 87, 43, 76, 34, 27, 24, 70, 58, 66, 38, 42, 71, 58, 60,
#        81, 33, 78, 39, 27, 76, 48, 21, 43, 44, 84, 35, 78, 28, 23, 85, 32,
#        30, 61, 39, 83, 23, 47, 55, 46, 49, 52, 19, 75, 76, 45, 59, 31, 51,
#        38, 27, 64, 67, 88, 43, 22, 47, 19, 18, 45, 57, 57, 40, 80, 54, 28,
#        31, 33, 56, 56, 54, 72, 32, 45, 85, 63, 51, 80, 33, 55, 71, 60, 20,
#        47, 20, 60, 60, 29, 28, 61, 66, 38, 88, 54, 32, 32, 38, 60, 42, 49,
#        77, 36, 23, 79, 82, 68, 79, 74, 79, 33, 70, 21, 75, 40, 37, 28, 34,
#        59, 42, 22, 28, 25, 78, 44, 69, 50, 63, 89, 75, 51, 28, 34, 20, 24,
#        80, 35, 23, 42, 34, 58, 35, 86, 89, 37, 65, 48, 42, 53, 52, 39, 50,
#        46, 36, 63, 58, 38, 86, 51, 63, 50, 37, 56, 64, 72, 47, 89, 18, 32,
#        28, 33, 48, 67, 51, 51, 60, 86, 55, 37, 26, 47, 39, 39, 41, 27, 48,
#        53, 38, 55, 86, 42, 50, 36, 83, 45, 52, 35, 57, 48, 39, 83, 63, 89,
#        58, 24, 28, 34, 86, 86, 84, 56, 88, 41, 37, 46, 68, 63, 39, 18, 56,
#        54, 49, 56, 82, 66, 73, 47, 35, 67, 25, 20, 53, 36, 39, 65, 56, 87,
#        84, 51, 21, 87, 29, 70, 18, 75, 84, 77, 27, 41, 57, 81, 58, 45, 89,
#        28, 31, 32, 27, 42, 46, 75, 20, 32, 52, 35, 27, 61, 66, 88, 38, 39,
#        23, 67, 67, 85, 21, 38, 34, 74, 78, 28, 46, 42, 65, 67, 86, 83, 69,
#        22, 26, 55, 34, 46, 44, 31])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=np.int64(28), count=np.int64(15))
